# %%
print(18 * '=', 'Implementação de Métodos Numéricos', 18 * '=')
print("""Alunos: George Pontes da Cunha
        Iago Sousa Bezerra de Menezes
        Gabriela Firmino Paz
        Sabrina Salomão de Souza""")


# Valor inicial
n = int(input('Digite quantidade de valores iniciais para d: ')) 
D = [None]*n #  duvida a = [1]*n ?  
for b in range(0, n):
    k = float(input('Digite o valor de d{}: '.format(b+1))) 
    D[b]=k 

# Função para teste
def teste(xi):
    print('Teste opção {}'.format(xi))


# Função de saída dentro de cada opção:
def saida():
    n=str(input("""Deseja sair? Digite 's' para sim e 'n' para não.  """))
    n=n.lower()
    if n=='s':
        x= False
        print('Você saiu.')
        return x
    elif n=="n":
        x=True  # type: bool
        return x
# Espaço para definir Funções
# def nr(xi):


# def nm(xi):


# def sec(xi):


Onmenu = True

while Onmenu==True:

    # Opções do menu
    op = int(input("""Para utilizar cada método, digite o número correspondente.

    1 - Método de Newton-Raphson.
    2 - Método de Newton modificado.
    3 - Método da Secante.
    4 - Comparativo entre métodos.
    10 - Sair do programa.

    Digite sua opção: """))





    # Executa opcao.
    if op == 1:
        print('Escolheu a opção 1: Método de Newton-Raphson.')
        teste(op)
    elif op == 2:
        print('Escolheu opção 2: Método de Newton Modificado.')
        teste(op)
    elif op == 3:
        print('Escolheu opção 3: Método da Secante.')
        print('A secante é calculada com base em intervalos (a0, a1) para cada valor de D')
        A0= [None]*n 
        A1= [None]*n
        for b in range(0, n):
            j = float(input('Digite o {}º valor para aj: '.format(b+1))) 
            A0[b]=j
            j = float(input('Digite o {}º valor para ak  .: '.format(b+1))) 
            A1[b]=k
    elif op == 4:
        print('Escolheu a opção 4: Comparativo.')
        teste(op)
    elif op == 10:
        print('Escolheu Sair.')
        Onmenu = False
# Out:
# ================== Implementação de Métodos Numéricos ==================
# Alunos: George Pontes da Cunha
#         Iago Sousa Bezerra de Menezes
#         Gabriela Firmino Paz
#         Sabrina Salomão de Souza
# Digite quantidade de valores iniciais para d: 5
# Digite o valor de d1: 5.2
# Digite o valor de d2: 3.0
# Digite o valor de d3: 7.56
# Digite o valor de d4: 1231
# Digite o valor de d5: 5125451
# Para utilizar cada método, digite o número correspondente.
#
#     1 - Método de Newton-Raphson.
#     2 - Método de Newton modificado.
#     3 - Método da Secante.
#     4 - Comparativo entre métodos.
#     10 - Sair do programa.
#
#     Digite sua opção: 1
# Escolheu a opção 1: Método de Newton-Raphson.
# Teste opção 1
# Para utilizar cada método, digite o número correspondente.
#
#     1 - Método de Newton-Raphson.
#     2 - Método de Newton modificado.
#     3 - Método da Secante.
#     4 - Comparativo entre métodos.
#     10 - Sair do programa.
#
#     Digite sua opção: 10
# Escolheu Sair.
