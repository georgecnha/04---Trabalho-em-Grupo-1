# %%
print(18 * '=', 'Implementação de Métodos Numéricos', 18 * '=')
print("""Alunos: George Pontes da Cunha
        Iago Sousa Bezerra de Menezes
        Gabriela Firmino Paz
        Sabrina Salomão de Souza""")
#============================ Método de Newton-Raphson =================================

def nr(a, d0):
    def f(xi):
        return (a*(exp(xi)) - 4*(xi**2)) 
    def df(xi):
        return ((a)*exp(xi)- 8*xi)
    k=0

    if abs(f(d0))<eps:
        d=d0     
    if df(d0)==0:
        print("ERRO! Derivada de d0 = 0, isto causa uma divisão por zero!") 
#Inicie as iterações k 
    else:
        k=1
        d=d0-(f(d0)/ df(d0))
        while abs(f(d))>eps and abs(d-d0)>eps and k<=maxIter:
            d0=d
            d=d0-(f(d0)/df(d0))
            Er=(abs(d0-d)/(d0)) 
            k=k+1
    if k==maxIter:
        print('Número máximo de iterações atingido.')
    
    print('| a{}={:.4f} | d0={:.4f} | d={:.4f} | Ea={:.4f} | Er={:.4f} | k={} | f(d)={:.4f} |'.format(b, a, d00, d, abs(d - d0), Er, k, f(d)))

#============================ Método de Newton Modificado ==============================

def nm(a,d0):
    def f(xi):
        y = a*(exp(xi)) - 4*(xi ** 2)
        return y

    def df(xi):
        y = a*(exp(xi)) + 8*(xi)
        return y


    if abs(f(d0))<eps:
        d = d0
    elif df(d0)<0:
        print('VALOR INVÁLIDO! Causa uma divisão por zero!')
    else:
        d00=d0
        d = d0 - (f(d0) / df(d00))
        k = 1
        while abs(f(d))>eps and abs(d - d0)> eps and k<maxIter:
            d0 = d
            d = d - (f(d) / df(d00))
            Er = abs((d - d0) / d0)
            k = k + 1
        if k == maxIter:
            print('Número máximo de iterações atingido!')
    print('| a{}={:.4f} | d0= {:.4f} | d={:.4f} | Ea={:.4f} | Er={:.4f} | k={} | f(d)={:.4f} |'.format(b, a, d00, d, abs(d - d0), Er, k, f(d)))
    

#============================ Método da Secante ========================================
    #a=A[b]

def secante(a, d0, d1):
    def f(xi):
        y = a*(exp(xi)) -4*(xi**2)
        return y
    d11=d1 #d00 e d1 são variáveis auxiliares que guardam os valores de d0 e d1
    d00=d0
    k=0
    if abs(f(d0))<eps:
        d=d0
    elif abs(f(d1))<eps and abs(d-d0)<eps:
        d=d
    else:
        k=1
        d=d1-((f(d1))*(d1-d0))/((f(d1))-(f(d0)))
        Er=abs((d1-d0)/d0)
        while abs(f(d))>eps and abs(d-d0)>=eps and k<maxIter:
            d1=d
            d=d1-((f(d1)*(d1-d0))/(f(d1)-f(d0)))
            d0=d1
            k=k+1
            Er=abs((d1-d0)/d0)
    print('| a{}={:.4f} | d0 = {:.4f} | d1= {:.4f} | d={:.4f} | Ea={:.4f} | Er={:.4f} | k={} | f(d)={:.4f} |'.format(b, a, d00, d1 , d, abs(d - d0), Er, k, f(d)))
    
#=================================MENU PRINCIPAL=============================================
from math import exp

# Valores iniciais

eps=float(input('Digite a tolerância a se utilizada: '))
n = int(input('Digite quantidade de valores iniciais para a: ')) 
A = [None]*n #  duvida a = [1]*n ?  
maxIter= 50
for b in range(0, n):
    k = float(input('Digite o valor de A{}: '.format(b+1))) 
    A[b]=k 

# Função para teste
def teste(xi):
    print('Teste opção {}'.format(xi))


# Função de saída dentro de cada opção:
def saida():
    n=str(input("""Deseja sair? Digite 's' para sim e 'n' para não.  """))
    n=n.lower()
    if n=='s':
        x= False
        print('Você saiu.')
        return x
    elif n=="n":
        x=True  # type: bool
        return x

#=================================OPÇÕES DO MENU PRINCIPAL================================
Onmenu = True

while Onmenu==True:

    # Opções do menu
    op = int(input("""Para utilizar cada método, digite o número correspondente.

    1 - Método de Newton-Raphson.
    2 - Método de Newton modificado.
    3 - Método da Secante.
    4 - Comparativo entre métodos.
    10 - Sair do programa.

    Digite sua opção: """))

    # Executa opcao.
    if op == 1:
        print('Escolheu a opção 1: Método de Newton-Raphson.')
        D0= [None]*n
        for b in range(0, n):
            j = float(input('Digite o {}º valor para d0: '.format(b+1))) 
            D0[b]=j
        print(38*'=', 'Resultados', 38*'=')
        for b in range(0, n):
            nr(A[b],D0[b])
    elif op == 2:
        print('Escolheu opção 2: Método de Newton Modificado.')
        D0= [None]*n 
        for b in range(0, n):
            j = float(input('Digite o {}º valor para d0: '.format(b+1))) 
            D0[b]=j
        print(38*'=', 'Resultados', 38*'=')
        for b in range(0, n):
            nm(A[b],D0[b])
    elif op == 3:
        print('Escolheu opção 3: Método da Secante.')
        print('A secante é calculada com base em intervalos (d0, d1) para cada valor de D')
        D0= [None]*n 
        D1= [None]*n
        for b in range(0, n):
            j = float(input('Digite o {}º valor para d0: '.format(b+1))) 
            D0[b]=j
            j = float(input('Digite o {}º valor para d1: '.format(b+1))) 
            D1[b]=k
        for b in range(0, n):
            secante(A[b], D0[b], D1[b])
            
    elif op == 4:
        print('Escolheu a opção 4: Comparativo.')
        
    elif op == 10:
        print('Escolheu Sair.')
        Onmenu = False
# Out:
# ================== Implementação de Métodos Numéricos ==================
# Alunos: George Pontes da Cunha
#         Iago Sousa Bezerra de Menezes
#         Gabriela Firmino Paz
#         Sabrina Salomão de Souza
# Digite a tolerância a se utilizada: 0.0001
# Digite quantidade de valores iniciais para a: 1
# Digite o valor de A1: 1
# Para utilizar cada método, digite o número correspondente.
#
#     1 - Método de Newton-Raphson.
#     2 - Método de Newton modificado.
#     3 - Método da Secante.
#     4 - Comparativo entre métodos.
#     10 - Sair do programa.
#
#     Digite sua opção: 3
# Escolheu opção 3: Método da Secante.
# A secante é calculada com base em intervalos (d0, d1) para cada valor de D
# Digite o 1º valor para d0: 0.5
# Digite o 1º valor para d1: 1.0
# | a0=1.0000 | d0 = 0.5000 | d1= 0.7144 | d=0.7148 | Ea=0.0004 | Er=0.0000 | k=4 | f(d)=0.0000 |
